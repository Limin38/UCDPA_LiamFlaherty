# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('./UCD_Orders_New_3.csv', low_memory=False)

# %%
df1.head()
# Out:
#    Unnamed: 0    Order_ID  Market_ID  \
# 0           0  3070781814        368
# 1           1  3070781814        368
# 2           2  3072577004        368
# 3           3  3071982114        368
# 4           4  2633440598        368
#
#                                          OrQuickNote       OrRefID  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           OST
# 3                                                NaN           OST
# 4  Vorkasse order placed on hold until payment is...  AWINDE320207
#
#    OrCancelled  OrShipPolicy  Customer_ID  OrCuTiID OrCuFirstName  ...  \
# 0        False         False   3886031494       NaN      Cornelia  ...
# 1        False         False   3886031494       NaN      Cornelia  ...
# 2         True         False   3880986614       NaN       Melanie  ...
# ...
