# %%
import pandas as pd
import numpy as np

# %%
Orders = pd.read_csv('./UCD_Orders .csv')

# %%
Orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Columns: 114 entries, OrID to event_date
# dtypes: bool(16), float64(40), int64(11), object(47)
# memory usage: 19.1+ MB

# %%
#drop dubicate orders
Orders.drop_duplicates(subset="OrID",keep=False, inplace=True)

# %%
Orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25000 entries, 0 to 24999
# Columns: 114 entries, OrID to event_date
# dtypes: bool(16), float64(40), int64(11), object(47)
# memory usage: 19.3+ MB

# %%
list(Orders.columns)
# Out:
# ['OrID',
#  'OrSoID',
#  'OrQuickNote',
#  'OrRefID',
#  'OrCancelled',
#  'OrShipPolicy',
#  'OrCuID',
#  'OrCuTiID',
#  'OrCuFirstName',
#  'OrCuMiddleName',
#  'OrCuLastName',
#  'OrCuAddress1',
#  'OrCuAddress2',
#  'OrCuCityName',
#  'OrCuStID',
#  'OrCuStName',
#  'OrCuPostalCode',
#  'OrCuCountryName',
#  'OrCuEmailAddress',
#  'OrFakeEmail',
#  'OrCuCompanyName',
#  'OrCuDOB',
#  'OrCuContactAtPhone',
#  'OrCuHomePhone',
#  'OrCuWorkPhone',
#  'OrCuCellPhone',
#  'OrCuFax',
#  'OrCuCcID',
#  'OrCuCcSpecific',
#  'OrExpires',
#  'OrFraudMsg',
#  'OrFraudClear',
#  'OrRanAutoFraudCheck',
#  'OrCrID',
#  'OrCreditCardFailed',
#  'OrCreditCardName',
#  'OrCreditCardNumber',
#  'OrCreditCardExpireDate',
#  'OrCreditCardCVV',
#  'OrCreditCardCall',
#  'OrCurrentBalance',
#  'OrCurrentTotal',
#  'OrRoDescription',
#  'OrRoID',
#  'OrMailReceipt',
#  'OrOsID',
#  'OrUsID',
#  'OrCheckOutID',
#  'OrComplete',
#  'OrCompleteDate',
#  'OrCustomerComment',
#  'OrOnHold',
# ...

# %%
#rename columns for better understanding
Orders.rename(columns = {"OrID": "Order_ID", "OrSoID": "Market_ID", "OrCuID": "Customer_ID", "OrMtID": "Payment_method_ID"}, inplace=True)

# %%
Orders.head()
# Out:
#      Order_ID  Market_ID OrQuickNote OrRefID  OrCancelled  OrShipPolicy  \
# 0  3071475194        321         NaN     OST        False         False
# 1  3070130524        321         NaN     OST        False         False
# 2  3072763064        321         NaN     OST        False         False
# 3  3072403784        321         NaN     OST        False         False
# 4  2843255691        321         NaN     NaN        False         False
#
#    Customer_ID  OrCuTiID OrCuFirstName OrCuMiddleName  ... OrSource  \
# 0   3742255964       NaN       Lyndsey            NaN  ...      NaN
# 1   3820141004       NaN        Sophie            NaN  ...      NaN
# 2   3955981304       NaN      Kayleigh            NaN  ...      NaN
# 3   3730804774       0.0         Kelly            NaN  ...      NaN
# 4    461433262       NaN         Jyoti            NaN  ...      NaN
#
#                             OrPtWFToken OrCompletionStatus OrPDSent  \
# ...

# %%
#remove UK market place 
Orders.drop(Orders[Orders['Market_ID'] == 321].index, inplace = True)

# %%
Orders.head()
# Out:
#          Order_ID  Market_ID  \
# 18993  3070781814        368
# 18994  3072577004        368
# 18995  3071982114        368
# 18996  2633440598        368
# 18997  1735508121        368
#
#                                              OrQuickNote       OrRefID  \
# 18993                                                NaN           NaN
# 18994                                                NaN           OST
# 18995                                                NaN           OST
# 18996  Vorkasse order placed on hold until payment is...  AWINDE320207
# 18997                                                NaN           OST
#
#        OrCancelled  OrShipPolicy  Customer_ID  OrCuTiID OrCuFirstName  \
# 18993        False         False   3886031494       NaN      Cornelia
# 18994         True         False   3880986614       NaN       Melanie
# 18995        False         False   3879233824       NaN        Ulrike
# 18996        False         False   5088315058       NaN         Eleni
# ...

# %%
Orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6007 entries, 18993 to 24999
# Columns: 114 entries, Order_ID to event_date
# dtypes: bool(16), float64(40), int64(11), object(47)
# memory usage: 4.6+ MB

# %%
#import Payment Method & Payment details list

PaymentMethod = pd.read_csv('./UCD_Payment method .csv')

# %%
PaymentDetails = pd.read_csv('./Payment details.csv')

# %%
PaymentDetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 71 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PyID                       31822 non-null  int64
#  1   PyOrID                     31822 non-null  int64
#  2   PyMtID                     31822 non-null  int64
#  3   PyPmID                     31822 non-null  int64
#  4   PyTotal                    31821 non-null  float64
#  5   PyOther                    9242 non-null   object
#  6   PyGcID                     31821 non-null  object
#  7   PyGwID                     22205 non-null  float64
#  8   PyCrID                     17748 non-null  float64
#  9   PyCreditCardName           17841 non-null  object
#  10  PyCreditCardNumber         17770 non-null  object
#  11  PyCreditCardExpireDate     16877 non-null  object
#  12  PyCreditCardTotalApplied   31790 non-null  float64
# ...

# %%
#merge payment details to orders
Orders_New = Orders.merge(PaymentDetails, left_on = 'Order_ID', right_on = 'PyOrID')

# %%
Orders_New.head()
# Out:
#      Order_ID  Market_ID                                        OrQuickNote  \
# 0  3070781814        368                                                NaN
# 1  3070781814        368                                                NaN
# 2  3072577004        368                                                NaN
# 3  3071982114        368                                                NaN
# 4  2633440598        368  Vorkasse order placed on hold until payment is...
#
#         OrRefID  OrCancelled  OrShipPolicy  Customer_ID  OrCuTiID  \
# 0           NaN        False         False   3886031494       NaN
# 1           NaN        False         False   3886031494       NaN
# 2           OST         True         False   3880986614       NaN
# 3           OST        False         False   3879233824       NaN
# 4  AWINDE320207        False         False   5088315058       NaN
#
#   OrCuFirstName OrCuMiddleName  ... PyPtWFToken PyParentPyID PyScID  \
# ...

# %%
Orders_New.head()
# Out:
#      Order_ID  Market_ID                                        OrQuickNote  \
# 0  3070781814        368                                                NaN
# 1  3070781814        368                                                NaN
# 2  3072577004        368                                                NaN
# 3  3071982114        368                                                NaN
# 4  2633440598        368  Vorkasse order placed on hold until payment is...
#
#         OrRefID  OrCancelled  OrShipPolicy  Customer_ID  OrCuTiID  \
# 0           NaN        False         False   3886031494       NaN
# 1           NaN        False         False   3886031494       NaN
# 2           OST         True         False   3880986614       NaN
# 3           OST        False         False   3879233824       NaN
# 4  AWINDE320207        False         False   5088315058       NaN
#
#   OrCuFirstName OrCuMiddleName  ... PyPtWFToken PyParentPyID PyScID  \
# ...

# %%
list(Orders_New.columns)
# Out:
# ['Order_ID',
#  'Market_ID',
#  'OrQuickNote',
#  'OrRefID',
#  'OrCancelled',
#  'OrShipPolicy',
#  'Customer_ID',
#  'OrCuTiID',
#  'OrCuFirstName',
#  'OrCuMiddleName',
#  'OrCuLastName',
#  'OrCuAddress1',
#  'OrCuAddress2',
#  'OrCuCityName',
#  'OrCuStID',
#  'OrCuStName',
#  'OrCuPostalCode',
#  'OrCuCountryName',
#  'OrCuEmailAddress',
#  'OrFakeEmail',
#  'OrCuCompanyName',
#  'OrCuDOB',
#  'OrCuContactAtPhone',
#  'OrCuHomePhone',
#  'OrCuWorkPhone',
#  'OrCuCellPhone',
#  'OrCuFax',
#  'OrCuCcID',
#  'OrCuCcSpecific',
#  'OrExpires',
#  'OrFraudMsg',
#  'OrFraudClear',
#  'OrRanAutoFraudCheck',
#  'OrCrID',
#  'OrCreditCardFailed',
#  'OrCreditCardName',
#  'OrCreditCardNumber',
#  'OrCreditCardExpireDate',
#  'OrCreditCardCVV',
#  'OrCreditCardCall',
#  'OrCurrentBalance',
#  'OrCurrentTotal',
#  'OrRoDescription',
#  'OrRoID',
#  'OrMailReceipt',
#  'OrOsID',
#  'OrUsID',
#  'OrCheckOutID',
#  'OrComplete',
#  'OrCompleteDate',
#  'OrCustomerComment',
#  'OrOnHold',
# ...

# %%
### selecting columns that are needed only - better than dropping as list too long 
Orders_New[['Order_ID', 'Market_ID', 'OrDateNew' ,'PyDateNew', 'PyMtID']]
# Out:
#         Order_ID  Market_ID            OrDateNew            PyDateNew  PyMtID
# 0     3070781814        368   2020-05-24 6:37:15   2020-05-24 6:37:09      48
# 1     3070781814        368   2020-05-24 6:37:15  2020-06-08 10:54:10      48
# 2     3072577004        368  2020-04-08 14:17:43  2020-04-08 14:17:39      48
# 3     3071982114        368   2020-06-02 5:18:00   2020-06-02 5:17:54      48
# 4     2633440598        368  2019-01-17 12:12:37  2019-01-17 12:12:32      18
# ...          ...        ...                  ...                  ...     ...
# 7982  2821361738        368   2020-05-18 8:37:38   2020-05-18 8:37:31       1
# 7983  3480727528        368  2020-12-11 11:58:20  2020-12-11 11:58:15       1
# 7984  3485924968        368  2021-02-28 15:42:06  2021-02-28 15:41:53       1
# 7985  3529197098        368   2021-03-13 0:46:06   2021-03-13 0:46:01       1
# 7986  2787581018        368  2019-12-11 17:20:26  2019-12-11 17:20:20       1
#
# [7987 rows x 5 columns]

# %%
Orders_New[['Order_ID', 'Market_ID', 'OrDateNew' ,'PyDateNew', 'PyMtID']]
Orders_New.to_csv("UCD_Orders_New_3.csv")

# %%
# keep only these columns in file
Orders_New.to_csv("UCD_Orders_New_3.csv")
