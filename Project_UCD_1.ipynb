# %%
import pandas as pd

# %%
contacts = pd.read_csv('./Contacts.csv')
Payments = pd.read_csv('./Payments.csv')

# %%
print(contacts.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SvyID                16000 non-null  int64
#  1   OrID                 16000 non-null  int64
#  2   WrapDate             16000 non-null  object
#  3   WrapTimeStamp        16000 non-null  object
#  4   SvyWrapTypeName      16000 non-null  object
#  5   WizardWrap           16000 non-null  int64
#  6   SvyReasonPrimary     16000 non-null  int64
#  7   WrapPrimaryReason    16000 non-null  object
#  8   WrapSecondaryReason  16000 non-null  object
#  9   Marketplace          16000 non-null  object
#  10  nthWrap              16000 non-null  int64
#  11  WrapBucket           16000 non-null  object
#  12  PaymentMethod        14232 non-null  object
#  13  PaymentTotal         15992 non-null  float64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 1.7+ MB
# None

# %%
print(contacts.info())
print(Payments.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SvyID                16000 non-null  int64
#  1   OrID                 16000 non-null  int64
#  2   WrapDate             16000 non-null  object
#  3   WrapTimeStamp        16000 non-null  object
#  4   SvyWrapTypeName      16000 non-null  object
#  5   WizardWrap           16000 non-null  int64
#  6   SvyReasonPrimary     16000 non-null  int64
#  7   WrapPrimaryReason    16000 non-null  object
#  8   WrapSecondaryReason  16000 non-null  object
#  9   Marketplace          16000 non-null  object
#  10  nthWrap              16000 non-null  int64
#  11  WrapBucket           16000 non-null  object
#  12  PaymentMethod        14232 non-null  object
#  13  PaymentTotal         15992 non-null  float64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 1.7+ MB
# None
# ...

# %%
contacts = pd.read_csv('./Contacts.csv')
Payments = pd.read_csv('./Payments.csv')

# %%
print(contacts.info())
print(Payments.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SvyID                16000 non-null  int64
#  1   OrID                 16000 non-null  int64
#  2   WrapDate             16000 non-null  object
#  3   WrapTimeStamp        16000 non-null  object
#  4   SvyWrapTypeName      16000 non-null  object
#  5   WizardWrap           16000 non-null  int64
#  6   SvyReasonPrimary     16000 non-null  int64
#  7   WrapPrimaryReason    16000 non-null  object
#  8   WrapSecondaryReason  16000 non-null  object
#  9   Marketplace          16000 non-null  object
#  10  nthWrap              16000 non-null  int64
#  11  WrapBucket           16000 non-null  object
#  12  PaymentMethod        14232 non-null  object
#  13  PaymentTotal         15992 non-null  float64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 1.7+ MB
# None
# ...

# %%
Contacts_final = contacts.merge(Payments, left_on = 'OrID', right_on = 'OrID')

# %%
print(contacts.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SvyID                16000 non-null  int64
#  1   OrID                 16000 non-null  int64
#  2   WrapDate             16000 non-null  object
#  3   WrapTimeStamp        16000 non-null  object
#  4   SvyWrapTypeName      16000 non-null  object
#  5   WizardWrap           16000 non-null  int64
#  6   SvyReasonPrimary     16000 non-null  int64
#  7   WrapPrimaryReason    16000 non-null  object
#  8   WrapSecondaryReason  16000 non-null  object
#  9   Marketplace          16000 non-null  object
#  10  nthWrap              16000 non-null  int64
#  11  WrapBucket           16000 non-null  object
#  12  PaymentMethod        14232 non-null  object
#  13  PaymentTotal         15992 non-null  float64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 1.7+ MB
# None

# %%
Contacts_final.head()
# Out:
#       SvyID        OrID   WrapDate      WrapTimeStamp SvyWrapTypeName  \
# 0  65048403  3445324328  1/10/2021  1/10/2021 8:39:19         Service
#
#    WizardWrap  SvyReasonPrimary WrapPrimaryReason         WrapSecondaryReason  \
# 0           0               156   Billing/Credits  Settle Outstanding Balance
#
#   Marketplace  nthWrap         WrapBucket PaymentMethod_x  PaymentTotal  \
# 0          DE        1  3.Billing_Credits        Vorkasse         55.99
#
#            OrderDate PaymentMethod_y  OrderTotal
# 0  1/6/2021 16:05:54        Vorkasse       55.99

# %%
Contacts_final.drop(['PaymentMethod_y'], axis= 'columns')
# Out:
#       SvyID        OrID   WrapDate      WrapTimeStamp SvyWrapTypeName  \
# 0  65048403  3445324328  1/10/2021  1/10/2021 8:39:19         Service
#
#    WizardWrap  SvyReasonPrimary WrapPrimaryReason         WrapSecondaryReason  \
# 0           0               156   Billing/Credits  Settle Outstanding Balance
#
#   Marketplace  nthWrap         WrapBucket PaymentMethod_x  PaymentTotal  \
# 0          DE        1  3.Billing_Credits        Vorkasse         55.99
#
#            OrderDate  OrderTotal
# 0  1/6/2021 16:05:54       55.99

# %%
Contacts_final.rename(columns={'SvyID':'Contact_ID','OrID': 'Order_ID','PaymentMethod_x':'PaymentMethod'}, inplace=True)

# %%
Contacts_final.head()
# Out:
#    Contact_ID    Order_ID   WrapDate      WrapTimeStamp SvyWrapTypeName  \
# 0    65048403  3445324328  1/10/2021  1/10/2021 8:39:19         Service
#
#    WizardWrap  SvyReasonPrimary WrapPrimaryReason         WrapSecondaryReason  \
# 0           0               156   Billing/Credits  Settle Outstanding Balance
#
#   Marketplace  nthWrap         WrapBucket PaymentMethod  PaymentTotal  \
# 0          DE        1  3.Billing_Credits      Vorkasse         55.99
#
#            OrderDate PaymentMethod_y  OrderTotal
# 0  1/6/2021 16:05:54        Vorkasse       55.99

# %%
Contacts_final.drop(['PaymentMethod_y'], axis= 'columns')
# Out:
#    Contact_ID    Order_ID   WrapDate      WrapTimeStamp SvyWrapTypeName  \
# 0    65048403  3445324328  1/10/2021  1/10/2021 8:39:19         Service
#
#    WizardWrap  SvyReasonPrimary WrapPrimaryReason         WrapSecondaryReason  \
# 0           0               156   Billing/Credits  Settle Outstanding Balance
#
#   Marketplace  nthWrap         WrapBucket PaymentMethod  PaymentTotal  \
# 0          DE        1  3.Billing_Credits      Vorkasse         55.99
#
#            OrderDate  OrderTotal
# 0  1/6/2021 16:05:54       55.99

# %%
print(Contacts_final.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Contact_ID           1 non-null      int64
#  1   Order_ID             1 non-null      int64
#  2   WrapDate             1 non-null      object
#  3   WrapTimeStamp        1 non-null      object
#  4   SvyWrapTypeName      1 non-null      object
#  5   WizardWrap           1 non-null      int64
#  6   SvyReasonPrimary     1 non-null      int64
#  7   WrapPrimaryReason    1 non-null      object
#  8   WrapSecondaryReason  1 non-null      object
#  9   Marketplace          1 non-null      object
#  10  nthWrap              1 non-null      int64
#  11  WrapBucket           1 non-null      object
#  12  PaymentMethod        1 non-null      object
#  13  PaymentTotal         1 non-null      float64
#  14  OrderDate            1 non-null      object
# ...

# %%
Contacts_final.drop(['PaymentMethod_y'], axis= 'columns')
print(Contacts_final.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Contact_ID           1 non-null      int64
#  1   Order_ID             1 non-null      int64
#  2   WrapDate             1 non-null      object
#  3   WrapTimeStamp        1 non-null      object
#  4   SvyWrapTypeName      1 non-null      object
#  5   WizardWrap           1 non-null      int64
#  6   SvyReasonPrimary     1 non-null      int64
#  7   WrapPrimaryReason    1 non-null      object
#  8   WrapSecondaryReason  1 non-null      object
#  9   Marketplace          1 non-null      object
#  10  nthWrap              1 non-null      int64
#  11  WrapBucket           1 non-null      object
#  12  PaymentMethod        1 non-null      object
#  13  PaymentTotal         1 non-null      float64
#  14  OrderDate            1 non-null      object
# ...

# %%
Contacts_final.drop(['PaymentMethod_y'], axis= 'columns')
# Out:
#    Contact_ID    Order_ID   WrapDate      WrapTimeStamp SvyWrapTypeName  \
# 0    65048403  3445324328  1/10/2021  1/10/2021 8:39:19         Service
#
#    WizardWrap  SvyReasonPrimary WrapPrimaryReason         WrapSecondaryReason  \
# 0           0               156   Billing/Credits  Settle Outstanding Balance
#
#   Marketplace  nthWrap         WrapBucket PaymentMethod  PaymentTotal  \
# 0          DE        1  3.Billing_Credits      Vorkasse         55.99
#
#            OrderDate  OrderTotal
# 0  1/6/2021 16:05:54       55.99

# %%
Contacts_final.head()
# Out:
#    Contact_ID    Order_ID   WrapDate      WrapTimeStamp SvyWrapTypeName  \
# 0    65048403  3445324328  1/10/2021  1/10/2021 8:39:19         Service
#
#    WizardWrap  SvyReasonPrimary WrapPrimaryReason         WrapSecondaryReason  \
# 0           0               156   Billing/Credits  Settle Outstanding Balance
#
#   Marketplace  nthWrap         WrapBucket PaymentMethod  PaymentTotal  \
# 0          DE        1  3.Billing_Credits      Vorkasse         55.99
#
#            OrderDate PaymentMethod_y  OrderTotal
# 0  1/6/2021 16:05:54        Vorkasse       55.99

# %%
Contacts_final.drop(['PaymentMethod_y'], axis= 'columns', inplace=True)

# %%
Contacts_final.head()
# Out:
#    Contact_ID    Order_ID   WrapDate      WrapTimeStamp SvyWrapTypeName  \
# 0    65048403  3445324328  1/10/2021  1/10/2021 8:39:19         Service
#
#    WizardWrap  SvyReasonPrimary WrapPrimaryReason         WrapSecondaryReason  \
# 0           0               156   Billing/Credits  Settle Outstanding Balance
#
#   Marketplace  nthWrap         WrapBucket PaymentMethod  PaymentTotal  \
# 0          DE        1  3.Billing_Credits      Vorkasse         55.99
#
#            OrderDate  OrderTotal
# 0  1/6/2021 16:05:54       55.99

# %%
Contacts_final.to_csv('Contacts_New.csv')

# %%
Contacts_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Contact_ID           1 non-null      int64
#  1   Order_ID             1 non-null      int64
#  2   WrapDate             1 non-null      object
#  3   WrapTimeStamp        1 non-null      object
#  4   SvyWrapTypeName      1 non-null      object
#  5   WizardWrap           1 non-null      int64
#  6   SvyReasonPrimary     1 non-null      int64
#  7   WrapPrimaryReason    1 non-null      object
#  8   WrapSecondaryReason  1 non-null      object
#  9   Marketplace          1 non-null      object
#  10  nthWrap              1 non-null      int64
#  11  WrapBucket           1 non-null      object
#  12  PaymentMethod        1 non-null      object
#  13  PaymentTotal         1 non-null      float64
#  14  OrderDate            1 non-null      object
# ...
